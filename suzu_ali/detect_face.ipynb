# %%
from icrawler.builtin import BingImageCrawler

# 広瀬すずの画像を取得
crawler = BingImageCrawler(storage={"root_dir": "./photo/normal/suzu"})
crawler.crawl(keyword="広瀬すず", max_num=250)
# Out:
# 2021-07-06 07:32:49,220 - INFO - icrawler.crawler - start crawling...
# 2021-07-06 07:32:49,220 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-07-06 07:32:49,220 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-07-06 07:32:49,220 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-07-06 07:32:49,979 - INFO - parser - parsing result page https://www.bing.com/images/async?q=広瀬すず&first=0
# 2021-07-06 07:32:50,621 - INFO - downloader - image #1	https://hochi.news/images/2020/06/24/20200624-OHT1I50093-L.jpg
# 2021-07-06 07:32:52,575 - INFO - downloader - image #2	https://www.jprime.jp/mwimgs/5/7/-/img_576986d280a4baabfc3bc497f7941c564160129.jpg
# 2021-07-06 07:32:53,184 - INFO - downloader - image #3	https://www.sanspo.com/geino/images/20201007/geo20100704000007-l1.jpg
# 2021-07-06 07:32:53,441 - INFO - downloader - image #4	https://www.sanspo.com/geino/images/20201006/geo20100623280023-p1.jpg
# ...

# %%
# 広瀬アリスの画像を取得
crawler = BingImageCrawler(storage={"root_dir": "./photo/normal/alice"})
crawler.crawl(keyword="広瀬アリス", max_num=250)
# Out:
# 2021-07-06 07:34:56,284 - INFO - icrawler.crawler - start crawling...
# 2021-07-06 07:34:56,285 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-07-06 07:34:56,287 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-07-06 07:34:56,290 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-07-06 07:34:56,990 - INFO - parser - parsing result page https://www.bing.com/images/async?q=広瀬アリス&first=0
# 2021-07-06 07:34:57,828 - INFO - downloader - image #1	https://www.machipara.com/wp-content/uploads/hirosearisu3-1242-2688.jpg
# 2021-07-06 07:34:58,542 - INFO - downloader - image #2	https://stat.ameba.jp/user_images/20190207/18/nofashionolife/21/0f/j/o0900090014352115779.jpg
# 2021-07-06 07:34:59,199 - INFO - downloader - image #3	https://i.daily.jp/gossip/2019/12/15/Images/f_12961025.jpg
# 2021-07-06 07:34:59,920 - INFO - downloader - image #4	https://quizjapan.com/wp-content/uploads/2018/05/jpp018807302-1-e1526894073567.jpg
# ...

# %%
import glob
import os
import cv2

classes = ['suzu','alice']
out_dir = "./photo/face/"
os.makedirs(out_dir, exist_ok=True)
for i in range(len(classes)):

    in_dir = "./photo/normal/"+classes[i]+"/*.jpg"
    in_jpg = glob.glob(in_dir)
    os.makedirs(out_dir + classes[i], exist_ok=True)
    # print(in_jpg)
    print(len(in_jpg))
    for num in range(len(in_jpg)):
        image=cv2.imread(str(in_jpg[num]))
        if image is None:
            print("Not open:",num)
            continue

        image_gs = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")


        face_list=cascade.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=2,minSize=(64,64))

        if len(face_list) > 0:
            for rect in face_list:
                x,y,width,height=rect
                image = image[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
                if image.shape[0]<64:
                    continue
                image = cv2.resize(image,(64,64))

                fileName=os.path.join(out_dir+"/"+classes[i],str(num)+".jpg")
                cv2.imwrite(str(fileName),image)
                print(str(num)+".jpgを保存しました.")

        else:
            print("no face")
            continue
        print(image.shape)
# Out:
# 183
# 0.jpgを保存しました.
# (64, 64, 3)
# 1.jpgを保存しました.
# (0, 0, 3)
# 2.jpgを保存しました.
# (0, 0, 3)
# 3.jpgを保存しました.
# (0, 0, 3)
# 4.jpgを保存しました.
# (64, 64, 3)
# 5.jpgを保存しました.
# (64, 64, 3)
# 6.jpgを保存しました.
# (0, 0, 3)
# 7.jpgを保存しました.
# (64, 64, 3)
# 8.jpgを保存しました.
# (0, 12, 3)
# 9.jpgを保存しました.
# (0, 0, 3)
# 10.jpgを保存しました.
# (0, 0, 3)
# 11.jpgを保存しました.
# (0, 0, 3)
# 12.jpgを保存しました.
# (64, 64, 3)
# 13.jpgを保存しました.
# (64, 64, 3)
# 14.jpgを保存しました.
# (0, 0, 3)
# 15.jpgを保存しました.
# (64, 64, 3)
# 16.jpgを保存しました.
# (0, 0, 3)
# 17.jpgを保存しました.
# (64, 64, 3)
# 18.jpgを保存しました.
# (64, 64, 3)
# 19.jpgを保存しました.
# (0, 0, 3)
# 20.jpgを保存しました.
# (64, 64, 3)
# 21.jpgを保存しました.
# (64, 64, 3)
# 22.jpgを保存しました.
# (64, 64, 3)
# 23.jpgを保存しました.
# (64, 64, 3)
# 24.jpgを保存しました.
# (64, 64, 3)
# 25.jpgを保存しました.
# (0, 0, 3)
# 26.jpgを保存しました.
# (64, 64, 3)
# 27.jpgを保存しました.
# (64, 64, 3)
# 28.jpgを保存しました.
# (64, 64, 3)
# no face
# 30.jpgを保存しました.
# (64, 64, 3)
# 31.jpgを保存しました.
# (0, 0, 3)
# 32.jpgを保存しました.
# (64, 64, 3)
# no face
# 34.jpgを保存しました.
# ...

# %% [markdown]
# # 調査対象

# %%
# 芸能人などの画像を取得
crawler = BingImageCrawler(storage={"root_dir": "./photo/normal/star"})
crawler.crawl(keyword="芸能人", max_num=250)
# Out:
# 2021-07-06 23:33:26,666 - INFO - icrawler.crawler - start crawling...
# 2021-07-06 23:33:26,667 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2021-07-06 23:33:26,672 - INFO - icrawler.crawler - starting 1 parser threads...
# 2021-07-06 23:33:26,676 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2021-07-06 23:33:27,141 - INFO - parser - parsing result page https://www.bing.com/images/async?q=芸能人&first=0
# 2021-07-06 23:33:27,316 - INFO - downloader - image #1	https://rankingoo.net/wp-content/uploads/2020/11/10095807/826fff9e96279e3aeae3fa681cc54b28.jpg
# 2021-07-06 23:33:27,550 - INFO - downloader - image #2	https://rankingoo.net/wp-content/uploads/2020/12/01162736/db3b9f4ee22c1e4283fc1458fd4fb3e1.jpg
# 2021-07-06 23:33:27,658 - INFO - downloader - image #3	https://rankingoo.net/wp-content/uploads/2020/10/20131523/c151b385ead2b4806ea9937cc065faae.jpg
# ...

# %%
import glob
import os
import cv2

classes = ['star']
out_dir = "./photo/face/"
os.makedirs(out_dir, exist_ok=True)
for i in range(len(classes)):

    in_dir = "./photo/normal/"+classes[i]+"/*.jpg"
    in_jpg = glob.glob(in_dir)
    os.makedirs(out_dir + classes[i], exist_ok=True)
    # print(in_jpg)
    print(len(in_jpg))
    for num in range(len(in_jpg)):
        image=cv2.imread(str(in_jpg[num]))
        if image is None:
            print("Not open:",num)
            continue

        image_gs = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")


        face_list=cascade.detectMultiScale(image_gs, scaleFactor=1.1, minNeighbors=2,minSize=(64,64))

        if len(face_list) > 0:
            for rect in face_list:
                x,y,width,height=rect
                image = image[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
                if image.shape[0]<64:
                    continue
                image = cv2.resize(image,(64,64))

                fileName=os.path.join(out_dir+"/"+classes[i],str(num)+".jpg")
                cv2.imwrite(str(fileName),image)
                print(str(num)+".jpgを保存しました.")

        else:
            print("no face")
            continue
        print(image.shape)
# Out:
# 164
# 0.jpgを保存しました.
# (64, 64, 3)
# 1.jpgを保存しました.
# (64, 64, 3)
# 2.jpgを保存しました.
# (64, 64, 3)
# 3.jpgを保存しました.
# (64, 64, 3)
# 4.jpgを保存しました.
# (0, 0, 3)
# 5.jpgを保存しました.
# (0, 0, 3)
# 6.jpgを保存しました.
# (64, 64, 3)
# 7.jpgを保存しました.
# (0, 0, 3)
# 8.jpgを保存しました.
# (64, 64, 3)
# 9.jpgを保存しました.
# (0, 0, 3)
# 10.jpgを保存しました.
# (64, 64, 3)
# 11.jpgを保存しました.
# (64, 64, 3)
# 12.jpgを保存しました.
# (64, 64, 3)
# 13.jpgを保存しました.
# (0, 0, 3)
# 14.jpgを保存しました.
# (64, 64, 3)
# 15.jpgを保存しました.
# (0, 0, 3)
# 16.jpgを保存しました.
# (0, 2, 3)
# 17.jpgを保存しました.
# (64, 64, 3)
# 18.jpgを保存しました.
# (64, 64, 3)
# 19.jpgを保存しました.
# (0, 0, 3)
# no face
# 21.jpgを保存しました.
# (64, 64, 3)
# 22.jpgを保存しました.
# (64, 64, 3)
# 23.jpgを保存しました.
# (0, 0, 3)
# 24.jpgを保存しました.
# (64, 64, 3)
# 25.jpgを保存しました.
# (64, 64, 3)
# 26.jpgを保存しました.
# (64, 64, 3)
# 27.jpgを保存しました.
# (0, 0, 3)
# 28.jpgを保存しました.
# (0, 0, 3)
# 29.jpgを保存しました.
# (64, 64, 3)
# 30.jpgを保存しました.
# (64, 64, 3)
# 31.jpgを保存しました.
# (64, 64, 3)
# 32.jpgを保存しました.
# (64, 64, 3)
# no face
# no face
# ...
